# %%
import numpy as np

# %%
print(f'ord("d")={ord("d")}')
print(f'chr({ord("d")}) = {chr(ord('d'))}')
# Out:
# ord("d")=100
# chr(100) = d

# %%
print(chr(0).__repr__())
print(chr(0))
# Out:
# '\x00'

# %%
print(f'String'+chr(0)+'String')
# Out:
# StringString

# %%
mystr = "Fuck Huijuan and Daniel"
print(f'mystr length is {len(mystr)}')
utf16_mystr = mystr.encode("utf-16")
print(f'utf16_mystr is: {utf16_mystr}')
print(f'utf16_mystr length is: {len(utf16_mystr)}')
utf16_mystr_list = list(utf16_mystr)
print(f'utf16_mystr_list is: {len(utf16_mystr_list)}')
# Out:
# mystr length is 23
# utf16_mystr is: b'\xff\xfeF\x00u\x00c\x00k\x00 \x00H\x00u\x00i\x00j\x00u\x00a\x00n\x00 \x00a\x00n\x00d\x00 \x00D\x00a\x00n\x00i\x00e\x00l\x00'
# utf16_mystr length is: 48
# utf16_mystr_list is: 48

# %%
mystr = "Fuck Huijuan and Daniel"
print(f'mystr length is {len(mystr)}')
utf8_mystr = mystr.encode("utf-8")
print(f'utf8_mystr is: {utf8_mystr}')
print(f'utf8_mystr length is: {len(utf8_mystr)}')
utf8_mystr_list = list(utf8_mystr)
print(f'utf16_mystr_list is: {len(utf8_mystr_list)}')
# Out:
# mystr length is 23
# utf8_mystr is: b'Fuck Huijuan and Daniel'
# utf8_mystr length is: 23
# utf16_mystr_list is: 23

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    for b in bytestring:
        print([bytes([b])])
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# Out:
# [b'h']
# [b'e']
# [b'l']
# [b'l']
# [b'o']
# 'hello'

# %%
decode_utf8_bytes_to_str_wrong("đđđdịt mẹ huijuan".encode("utf-8"))
# Out:
# [b'\xc4']
# [b'\x91']
# [b'\xc4']
# [b'\x91']
# [b'\xc4']
# [b'\x91']
# [b'd']
# [b'\xe1']
# [b'\xbb']
# [b'\x8b']
# [b't']
# [b' ']
# [b'm']
# [b'\xe1']
# [b'\xba']
# [b'\xb9']
# [b' ']
# [b'h']
# [b'u']
# [b'i']
# [b'j']
# [b'u']
# [b'a']
# [b'n']
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 decode_utf8_bytes_to_str_wrong("đđđdịt mẹ huijuan".encode("utf-8"))
#
# Cell In[14], line 4, in decode_utf8_bytes_to_str_wrong(bytestring)
#       2 for b in bytestring:
#       3     print([bytes([b])])
# ----> 4 return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc4 in position 0: unexpected end of data

# %%
def find_two_byte_seq():
    for i in range(256):
        for j in range(256):
            bytelist = [i, j]
            bytestr = bytes(bytelist)
            try:
                decoded_char = bytestr.decode("utf-8")
            except:
                print(f"i = {i}, j = {j} found!")
                return

find_two_byte_seq()
# Out:
# i = 0, j = 128 found!

# %%
import regex as re 
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
re.findall(PAT, "some text that i'll pre-tokenize")
# Out:
# ['some', ' text', ' that', ' i', "'ll", ' pre', '-', 'tokenize']
